# %% [markdown]
# # Aula 11 &mdash; Visualização interativa de dados com Bokeh (Parte 2)
#
# Renato Vimieiro
#
# rv2 {em} cin.ufpe.br
#
# abril 2017

# %% [markdown]
# ## Introdução
#
# Na aula anterior vimos como criar gráficos com a interface básica de Bokeh. Como vimos, a interface básica valoriza facilidade de geração de visualizações sobre customização. Se quisermos criar visualizações adaptadas ao contexto da aplicação em que estamos trabalhando, então devemos usar a interface intermediária, ajustando detalhes com alguns itens da interface avançada. Nesta aula veremos como criar gráficos com a interface intermediária `bokeh.plotting`.
#
# Começamos por carregar algumas bibliotecas.

# %%
import pandas as pd
import numpy as np

import bokeh.charts as charts
from bokeh.plotting import figure, show
from bokeh.io import output_notebook, push_notebook
from bokeh.models import (Range1d, NumeralTickFormatter, 
                          FixedTicker, Legend, DatetimeTickFormatter,
                          CategoricalColorMapper, PreText, BoxAnnotation)
from bokeh.palettes import Set1_7
from bokeh.layouts import gridplot
from bokeh.core.properties import field

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9c1daebf-a257-4bf4-b242-373e84956b7d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Dados
#
# Para ilustrar o funcionamento da biblioteca, vamos utilizar os dados do IPCA de 8 regiões metropolitanas do país. Os dados foram obtidos do site do IBGE (http://seriesestatisticas.ibge.gov.br/lista_tema.aspx?op=0&de=52&no=11). Foram obtidas as séries históricas do IPCA mensais desde janeiro de 1991 até julho de 2016.
#
# As séries estão dividas em vários arquivos. Dessa forma, teremos de carregá-los um a um para depois concatená-los em um único data frame.

# %%
x = ! ls ../2017.1/data/ibge/ipca*
print(x)
# Out:
# ['../2017.1/data/ibge/ipca-reg-metropolitana-ago91_jul99.csv', '../2017.1/data/ibge/ipca-reg-metropolitana-jan12_jul16.csv', '../2017.1/data/ibge/ipca-reg-metropolitana-jul06_dez11.csv', '../2017.1/data/ibge/ipca-reg-metropolitanas-ago99_jun06.csv']

# %%
ipca = pd.concat([pd.read_csv(a,index_col=[0,1],header=0,sep='\t',na_values=['nan','-'],
                              decimal=',', ) for a in x], axis=1)
ipca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 109 entries, (Belem - PA, 1,Alimentacao e bebidas) to (Sao Paulo - SP, Indice geral)
# Columns: 306 entries, jan/91 to jun/06
# dtypes: float64(306)
# memory usage: 261.1+ KB

# %% [markdown]
# Como veremos, é mais fácil trabalhar com os dados no formato longo. Portanto, vamos convertê-los para o formato usando a função `pandas.melt`.

# %%
ipcalong = pd.melt(ipca.reset_index(),id_vars=['Regiao','OPCAO'],var_name='mes',value_name='ipca')
ipcalong.head(10)
# Out:
#        Regiao                        OPCAO     mes   ipca
# 0  Belem - PA      1,Alimentacao e bebidas  jan/91  21.08
# 1  Belem - PA                  2,Habitacao  jan/91  25.65
# 2  Belem - PA      3,Artigos de residencia  jan/91  14.49
# 3  Belem - PA                  4,Vestuario  jan/91   9.54
# 4  Belem - PA   5,Transporte e comunicacao  jan/91  17.18
# 5  Belem - PA                5,Transportes  jan/91    NaN
# 6  Belem - PA  6,Saude e cuidados pessoais  jan/91  29.30
# 7  Belem - PA          7,Despesas pessoais  jan/91  31.70
# 8  Belem - PA                   8,Educacao  jan/91    NaN
# 9  Belem - PA                9,Comunicacao  jan/91    NaN

# %% [markdown]
# As datas referentes aos índices estão no formato de string. Assim, devemos convertê-las para `datetime` antes de seguirmos a análise. Como os meses foram abreviados em português, precisamos mudar o `locale` para que a string de formatação de datas consiga interpretá-los corretamente.

# %%
import locale
locale.setlocale(locale.LC_ALL, '')
# Out:
# 'pt_BR.UTF-8'

# %%
ipcalong.mes = pd.to_datetime(ipcalong.mes.str.title(),format='%b/%y')
ipcalong.ipca = ipcalong.ipca.values/100
ipcalong.head()
# Out:
#        Regiao                       OPCAO        mes    ipca
# 0  Belem - PA     1,Alimentacao e bebidas 1991-01-01  0.2108
# 1  Belem - PA                 2,Habitacao 1991-01-01  0.2565
# 2  Belem - PA     3,Artigos de residencia 1991-01-01  0.1449
# 3  Belem - PA                 4,Vestuario 1991-01-01  0.0954
# 4  Belem - PA  5,Transporte e comunicacao 1991-01-01  0.1718

# %% [markdown]
# ## Tipo (fonte) de dados para Bokeh
#
# Bokeh define um tipo de dados específico para ser usado nas visualizações. Os dados devem ser definidos como tabelas, em que cada coluna possui apenas valores escalares. A classe que define esse tipo é a `ColumnDataSource`, a qual pode ser importada de `bokeh.models`. O construtor da classe funciona aceita um dicionário ou um data frame como parâmetro. Os dados são armazenados internamente como um dicionário (`ColumnDataSource.data`). Esse dicionário será enviado ao backend de Javascript de Bokeh para ser usado nas visualizações.

# %%
from bokeh.models import ColumnDataSource

# %% [markdown]
# Vamos criar um conjunto de dados somente com os dados do IPCA geral (ele é composto por vários itens/categorias que são avaliadas separadamente).

# %%
source = ColumnDataSource(ipcalong[ipcalong.OPCAO == 'Indice geral'])

# %% [markdown]
# ## Gramática dos gráficos
#
# Bokeh segue uma ideia que tem sido bastante recorrente entre as diversas bibliotecas de visualização: a ideia de se especificar uma gramática para construir um gráfico. Um gráfico é uma área de desenho (canvas). Sobre essa área, elementos são agregados. Em outras palavras, agregam-se os eixos, marcadores, linhas, etc. Cada um desses elementos visuais possui suas propriedades que podem ser alteradas conforme a necessidade. Dessa forma, um gráfico é a sobreposição desses elementos visuais sobre a área de desenho.
#
# A área de desenho é definida em `bokeh.plotting` pela função `figure`. Ela instancia essa área e a retorna como resultado da chamada.

# %%
p = figure(plot_height=400,plot_width=800,toolbar_location='above',
           tools="pan,box_select,tap,box_zoom,lasso_select,reset")

# %% [markdown]
# Uma vez que o gráfico tenha sido populado, pode-se visualizá-lo com a função `show`, tal qual fazíamos com os gráficos simples. De fato, eles são figuras em que certas propriedades são pré-definidas.

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dd274920-32d7-475b-81f9-1863e129d6ae"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dd274920-32d7-475b-81f9-1863e129d6ae");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dd274920-32d7-475b-81f9-1863e129d6ae");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dd274920-32d7-475b-81f9-1863e129d6ae' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"eeec4a6d-d9cb-4eba-bb28-34ef8c749912":{"roots":{"references":[{"attributes":{"plot":{"id":"aac5ad1d-7cbf-443e-99cb-1dc0f925b014","subtype":"Figure","type":"Plot"},"ticker":{"id":"20c0b3d4-8b07-4087-a98c-221876891539","type":"BasicTicker"}},"id":"87494efe-f57b-45c6-9c45-095979080e21","type":"Grid"},{"attributes":{"formatter":{"id":"0de64f7c-0263-4821-9c89-cc2fb625e582","type":"BasicTickFormatter"},"plot":{"id":"aac5ad1d-7cbf-443e-99cb-1dc0f925b014","subtype":"Figure","type":"Plot"},"ticker":{"id":"20c0b3d4-8b07-4087-a98c-221876891539","type":"BasicTicker"}},"id":"d021b600-550c-477a-8503-a2a086181f90","type":"LinearAxis"},{"attributes":{"below":[{"id":"d021b600-550c-477a-8503-a2a086181f90","type":"LinearAxis"}],"left":[{"id":"a0c32aa1-1033-4e3b-854c-5478583e2b52","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"d021b600-550c-477a-8503-a2a086181f90","type":"LinearAxis"},{"id":"87494efe-f57b-45c6-9c45-095979080e21","type":"Grid"},{"id":"a0c32aa1-1033-4e3b-854c-5478583e2b52","type":"LinearAxis"},{"id":"3d69cc24-65ce-4d99-adeb-237755215097","type":"Grid"},{"id":"699cedcb-8ca4-45c9-919d-ac178c6fb539","type":"BoxAnnotation"},{"id":"f48108cd-36b7-4439-b3a2-c5d4eb73ad8c","type":"BoxAnnotation"},{"id":"be98aacb-b79d-4e3a-9d5c-df9918703ea9","type":"PolyAnnotation"}],"title":{"id":"c7e9287c-661b-4f84-b84c-0c5f7d257a62","type":"Title"},"tool_events":{"id":"91761e94-f25e-4135-8a98-3385e93d8f6c","type":"ToolEvents"},"toolbar":{"id":"00c74fd9-1251-4f6d-8401-e2697871a1c2","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"b76f9ce2-8890-459d-bb2e-81b9f785bb6f","type":"DataRange1d"},"y_range":{"id":"2842e9cb-e376-47c0-90c2-ae0533cddf9a","type":"DataRange1d"}},"id":"aac5ad1d-7cbf-443e-99cb-1dc0f925b014","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"91761e94-f25e-4135-8a98-3385e93d8f6c","type":"ToolEvents"},{"attributes":{},"id":"e7cdeffe-650b-400e-9de5-1a08e2b61580","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"f48108cd-36b7-4439-b3a2-c5d4eb73ad8c","type":"BoxAnnotation"},"plot":{"id":"aac5ad1d-7cbf-443e-99cb-1dc0f925b014","subtype":"Figure","type":"Plot"}},"id":"8e9674a0-7b21-4e9d-a88a-ffa6854f6399","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"699cedcb-8ca4-45c9-919d-ac178c6fb539","type":"BoxAnnotation"},{"attributes":{},"id":"20c0b3d4-8b07-4087-a98c-221876891539","type":"BasicTicker"},{"attributes":{"callback":null,"overlay":{"id":"be98aacb-b79d-4e3a-9d5c-df9918703ea9","type":"PolyAnnotation"},"plot":{"id":"aac5ad1d-7cbf-443e-99cb-1dc0f925b014","subtype":"Figure","type":"Plot"}},"id":"83745547-8d92-4c2d-bb06-554eb9b37530","type":"LassoSelectTool"},{"attributes":{},"id":"0de64f7c-0263-4821-9c89-cc2fb625e582","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"aac5ad1d-7cbf-443e-99cb-1dc0f925b014","subtype":"Figure","type":"Plot"},"ticker":{"id":"4f25b702-f477-4e55-9751-01af2309d58c","type":"BasicTicker"}},"id":"3d69cc24-65ce-4d99-adeb-237755215097","type":"Grid"},{"attributes":{"callback":null,"plot":{"id":"aac5ad1d-7cbf-443e-99cb-1dc0f925b014","subtype":"Figure","type":"Plot"}},"id":"496af786-15a1-46a6-993e-dcaa261c19db","type":"TapTool"},{"attributes":{"plot":null,"text":""},"id":"c7e9287c-661b-4f84-b84c-0c5f7d257a62","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f48108cd-36b7-4439-b3a2-c5d4eb73ad8c","type":"BoxAnnotation"},{"attributes":{"plot": ...

# %% [markdown]
# Como vemos, uma vez que não adicionamos elementos visuais à figura, a área de desenho permanece vazia, exceto pelos elementos pré-definidos (barra de ferramentas).
#
# Os objetos criados possuem diversos métodos para se adicionar os elementos visuais ao gráfico. Esses elementos são chamados de `Glyph` em Bokeh. Existe uma lista bem ampla de símbolos/marcadores que podem ser usados em Bokeh. Essa lista encontra-se no manual da biblioteca.
#
# Em nosso primeiro exemplo, vamos criar um gráfico de dispersão acrescentando círculos à área de desenho.

# %%
p.circle('mes','ipca',source=source)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4d8c52da-abd6-4582-9f1a-37df357d0765"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4d8c52da-abd6-4582-9f1a-37df357d0765");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4d8c52da-abd6-4582-9f1a-37df357d0765");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4d8c52da-abd6-4582-9f1a-37df357d0765' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e4d3fec7-4e5a-4dba-a551-77acf8fd3917":{"roots":{"references":[{"attributes":{"callback":null,"overlay":{"id":"be98aacb-b79d-4e3a-9d5c-df9918703ea9","type":"PolyAnnotation"},"plot":{"id":"aac5ad1d-7cbf-443e-99cb-1dc0f925b014","subtype":"Figure","type":"Plot"}},"id":"83745547-8d92-4c2d-bb06-554eb9b37530","type":"LassoSelectTool"},{"attributes":{"plot":{"id":"aac5ad1d-7cbf-443e-99cb-1dc0f925b014","subtype":"Figure","type":"Plot"},"ticker":{"id":"20c0b3d4-8b07-4087-a98c-221876891539","type":"BasicTicker"}},"id":"87494efe-f57b-45c6-9c45-095979080e21","type":"Grid"},{"attributes":{"formatter":{"id":"0de64f7c-0263-4821-9c89-cc2fb625e582","type":"BasicTickFormatter"},"plot":{"id":"aac5ad1d-7cbf-443e-99cb-1dc0f925b014","subtype":"Figure","type":"Plot"},"ticker":{"id":"20c0b3d4-8b07-4087-a98c-221876891539","type":"BasicTicker"}},"id":"d021b600-550c-477a-8503-a2a086181f90","type":"LinearAxis"},{"attributes":{},"id":"91761e94-f25e-4135-8a98-3385e93d8f6c","type":"ToolEvents"},{"attributes":{},"id":"e7cdeffe-650b-400e-9de5-1a08e2b61580","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"f48108cd-36b7-4439-b3a2-c5d4eb73ad8c","type":"BoxAnnotation"},"plot":{"id":"aac5ad1d-7cbf-443e-99cb-1dc0f925b014","subtype":"Figure","type":"Plot"}},"id":"8e9674a0-7b21-4e9d-a88a-ffa6854f6399","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"699cedcb-8ca4-45c9-919d-ac178c6fb539","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"d021b600-550c-477a-8503-a2a086181f90","type":"LinearAxis"}],"left":[{"id":"a0c32aa1-1033-4e3b-854c-5478583e2b52","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"d021b600-550c-477a-8503-a2a086181f90","type":"LinearAxis"},{"id":"87494efe-f57b-45c6-9c45-095979080e21","type":"Grid"},{"id":"a0c32aa1-1033-4e3b-854c-5478583e2b52","type":"LinearAxis"},{"id":"3d69cc24-65ce-4d99-adeb-237755215097","type":"Grid"},{"id":"699cedcb-8ca4-45c9-919d-ac178c6fb539","type":"BoxAnnotation"},{"id":"f48108cd-36b7-4439-b3a2-c5d4eb73ad8c","type":"BoxAnnotation"},{"id":"be98aacb-b79d-4e3a-9d5c-df9918703ea9","type":"PolyAnnotation"},{"id":"6aa7b26c-7536-4310-afd5-1e9f40f27f81","type":"GlyphRenderer"}],"title":{"id":"c7e9287c-661b-4f84-b84c-0c5f7d257a62","type":"Title"},"tool_events":{"id":"91761e94-f25e-4135-8a98-3385e93d8f6c","type":"ToolEvents"},"toolbar":{"id":"00c74fd9-1251-4f6d-8401-e2697871a1c2","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"b76f9ce2-8890-459d-bb2e-81b9f785bb6f","type":"DataRange1d"},"y_range":{"id":"2842e9cb-e376-47c0-90c2-ae0533cddf9a","type":"DataRange1d"}},"id":"aac5ad1d-7cbf-443e-99cb-1dc0f925b014","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["mes","index","Regiao","ipca","OPCAO"],"data":{"OPCAO":["Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice g ...

# %% [markdown]
# Definimos no método que a coluna mês correspondia ao eixo x, enquanto a coluna ipca correspondia ao eixo y do conjunto de dados especificado em `source`.
#
# A figura gerada é, no entanto, pouco informativa, pois a informação da região não está presente. Além disso, os eixos estão formatados de maneira estranha. O eixo x, por exemplo, deveria exibir as datas e exibe valores absurdamente grandes. Assim, também corrigiremos a formatação dos eixos.

# %%
p = figure(plot_height=400,plot_width=800,toolbar_location='above',
           tools="pan,box_select,tap,box_zoom,lasso_select,reset")

p.xaxis.formatter = DatetimeTickFormatter(months='%b/%Y')
p.yaxis.formatter = NumeralTickFormatter(format='0.00%')

color_mapper = CategoricalColorMapper(
    factors = list(ipcalong.Regiao.unique()),
    palette = ['#8dd3c7', '#ffffb3', '#bebada', '#fb8072', 
'#80b1d3', '#fdb462', '#b3de69', '#e41a1c',
'#377eb8', '#4daf4a', '#984ea3']
)

p.circle('mes','ipca',source=source,
         color={'field':'Regiao', 'transform':color_mapper},
         fill_alpha=0.3,
         legend=field('Regiao'))

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9b5f72d7-781b-46cb-8bb1-eaefc98cac94"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9b5f72d7-781b-46cb-8bb1-eaefc98cac94");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9b5f72d7-781b-46cb-8bb1-eaefc98cac94");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9b5f72d7-781b-46cb-8bb1-eaefc98cac94' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"45bfb878-55b0-4007-965f-9933b139b61c":{"roots":{"references":[{"attributes":{"plot":{"id":"644d1919-c849-4174-a26d-e7b1c604f90c","subtype":"Figure","type":"Plot"}},"id":"5fe83fb7-73bd-4e0b-9ae0-e8c4e880dc26","type":"PanTool"},{"attributes":{},"id":"85f77609-df43-4757-aba9-2567053c07db","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"e2fc96ab-267c-4776-94ef-28e9ca899671","type":"PolyAnnotation"},{"attributes":{"formatter":{"id":"2b3e48e0-fa76-4c57-b79f-73f1a6c10c84","type":"DatetimeTickFormatter"},"plot":{"id":"644d1919-c849-4174-a26d-e7b1c604f90c","subtype":"Figure","type":"Plot"},"ticker":{"id":"9f2f9f48-f324-451c-bdac-3cdb1fc4d956","type":"BasicTicker"}},"id":"02c23f09-2856-4544-b036-98818cb6e72b","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5fe83fb7-73bd-4e0b-9ae0-e8c4e880dc26","type":"PanTool"},{"id":"c7c2527d-166e-4a13-b4fb-45476029eef1","type":"BoxSelectTool"},{"id":"63e750ed-ae52-47ed-955e-6cae188e0ac0","type":"TapTool"},{"id":"51cf2845-4899-412e-af51-1b1ed4358001","type":"BoxZoomTool"},{"id":"df3e7a1e-2cc9-4ed1-b422-4935d3ccd11e","type":"LassoSelectTool"},{"id":"5c0e07d4-0577-472c-801d-a38bcb54f010","type":"ResetTool"}]},"id":"79cd1293-ea21-45d3-86d0-a0c391b038a9","type":"Toolbar"},{"attributes":{"callback":null,"overlay":{"id":"e2fc96ab-267c-4776-94ef-28e9ca899671","type":"PolyAnnotation"},"plot":{"id":"644d1919-c849-4174-a26d-e7b1c604f90c","subtype":"Figure","type":"Plot"}},"id":"df3e7a1e-2cc9-4ed1-b422-4935d3ccd11e","type":"LassoSelectTool"},{"attributes":{"callback":null,"column_names":["mes","index","Regiao","ipca","OPCAO"],"data":{"OPCAO":["Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indi ...

# %% [markdown]
# Bokeh permite criar interatividade inclusive com a legenda, definindo o comportamento que deve ocorrer quando clicamos sobre ela. Vamos definir que os dados sejam ocultados quando clicarmos.
#
# Outra possibilidade que temos agora com a interface intermediária é de mover a legenda para fora da área de plotagem. Podemos colocá-la, por exemplo, no lado de fora à direita.

# %%
p.legend.click_policy = 'hide'
p.legend.location = (10,120)
p.right.append(p.legend[0])

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="34274db7-2307-4601-9276-86d7c85675cf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("34274db7-2307-4601-9276-86d7c85675cf");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("34274db7-2307-4601-9276-86d7c85675cf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '34274db7-2307-4601-9276-86d7c85675cf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d20a1598-2b06-42c9-8fff-aba01bc538fc":{"roots":{"references":[{"attributes":{"plot":{"id":"644d1919-c849-4174-a26d-e7b1c604f90c","subtype":"Figure","type":"Plot"}},"id":"5fe83fb7-73bd-4e0b-9ae0-e8c4e880dc26","type":"PanTool"},{"attributes":{},"id":"85f77609-df43-4757-aba9-2567053c07db","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"e2fc96ab-267c-4776-94ef-28e9ca899671","type":"PolyAnnotation"},{"attributes":{"formatter":{"id":"2b3e48e0-fa76-4c57-b79f-73f1a6c10c84","type":"DatetimeTickFormatter"},"plot":{"id":"644d1919-c849-4174-a26d-e7b1c604f90c","subtype":"Figure","type":"Plot"},"ticker":{"id":"9f2f9f48-f324-451c-bdac-3cdb1fc4d956","type":"BasicTicker"}},"id":"02c23f09-2856-4544-b036-98818cb6e72b","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5fe83fb7-73bd-4e0b-9ae0-e8c4e880dc26","type":"PanTool"},{"id":"c7c2527d-166e-4a13-b4fb-45476029eef1","type":"BoxSelectTool"},{"id":"63e750ed-ae52-47ed-955e-6cae188e0ac0","type":"TapTool"},{"id":"51cf2845-4899-412e-af51-1b1ed4358001","type":"BoxZoomTool"},{"id":"df3e7a1e-2cc9-4ed1-b422-4935d3ccd11e","type":"LassoSelectTool"},{"id":"5c0e07d4-0577-472c-801d-a38bcb54f010","type":"ResetTool"}]},"id":"79cd1293-ea21-45d3-86d0-a0c391b038a9","type":"Toolbar"},{"attributes":{"callback":null,"overlay":{"id":"e2fc96ab-267c-4776-94ef-28e9ca899671","type":"PolyAnnotation"},"plot":{"id":"644d1919-c849-4174-a26d-e7b1c604f90c","subtype":"Figure","type":"Plot"}},"id":"df3e7a1e-2cc9-4ed1-b422-4935d3ccd11e","type":"LassoSelectTool"},{"attributes":{"callback":null,"column_names":["mes","index","Regiao","ipca","OPCAO"],"data":{"OPCAO":["Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indice geral","Indi ...

# %% [markdown]
# Infelizmente, como todos os itens foram gerados com a mesma chamada a `circle`, só é possível exibir ou ocultar todos de uma única vez. A solução para esse problema é criar os elementos um por vez e gerar uma legenda para eles em seguida.
#
# Para produzir a visualização mencionada, precisamos voltar os dados para o formato amplo, onde as colunas serão os IPCAs nas regiões.

# %%
df = pd.pivot_table(ipcalong,columns='Regiao',values='ipca',index=['mes','OPCAO']).reset_index()
source = ColumnDataSource(df[df.OPCAO=='Indice geral'].drop('OPCAO',axis=1))

# %% [markdown]
# Precisamos criar um mapa de cores, uma vez que não usaremos mais o color mapper de Bokeh.

# %%
corRegiao = dict(zip(ipcalong.Regiao.unique(),['#8dd3c7', '#ffffb3', '#bebada', '#fb8072', 
'#80b1d3', '#fdb462', '#b3de69', '#e41a1c',
'#377eb8', '#4daf4a', '#984ea3']))
corRegiao
# Out:
# {'Belem - PA': '#8dd3c7',
#  'Belo Horizonte - MG': '#ffffb3',
#  'Curitiba - PR': '#bebada',
#  'Fortaleza - CE': '#fb8072',
#  'Grande Vitoria - ES': '#80b1d3',
#  'Porto Alegre - RS': '#fdb462',
#  'Recife - PE': '#b3de69',
#  'Rio de Janeiro - RJ': '#e41a1c',
#  'Salvador - BA': '#377eb8',
#  'Sao Paulo - SP': '#4daf4a'}

# %%
p = figure(plot_height=400,plot_width=800,toolbar_location='above',
           tools="pan,box_select,tap,box_zoom,lasso_select,reset")

p.xaxis.formatter = DatetimeTickFormatter(months='%b/%Y')
p.yaxis.formatter = NumeralTickFormatter(format='0.00%')

glyphs = {d : [p.circle('mes',d,source=source,
                        color=corRegiao[d], fill_alpha=0.3)] 
          for d in ipcalong.Regiao.unique()}

legend = Legend(items=list(glyphs.items()), location=(10, 120))
legend.click_policy='hide'
p.add_layout(legend,'right')

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2
},{"attributes":{"data_source":{"id":"d0c74e17-d463-4558-9116-2a3cb40fa9ad","type":"ColumnDataSource"},"glyph":{"id":"3b7c6cec-4413-404b- ...

# %% [markdown]
# Podemos ainda acrescentar uma linha de tendência dos dados. Para isso, obtemos os coeficientes da reta usando regressão linear disponível em `numpy` (`numpy.polyfit`) e criamos uma função a partir dos mesmos com o auxílio de `numpy.poly1d`.

# %%
d = ipcalong[ipcalong.OPCAO=='Indice geral'].dropna()
coef = np.polyfit((d['mes'] - pd.datetime(1970,1,1)).dt.total_seconds(), d.ipca,deg=1)
func_ipca = np.poly1d(coef)
print(coef)
# Out:
# [ -2.04202954e-10   2.65492788e-01]

# %%
p.line(x=source.data['mes'],
       y=func_ipca((source.data['mes'] - pd.datetime(1970,1,1)).dt.total_seconds()),
      color='black')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1e1ee6a1-a8df-4f73-912f-25ce10f48db7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1e1ee6a1-a8df-4f73-912f-25ce10f48db7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1e1ee6a1-a8df-4f73-912f-25ce10f48db7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1e1ee6a1-a8df-4f73-912f-25ce10f48db7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"925db231-c92a-4e4c-966e-cb9b33d004f5":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"mes"},"y":{"field":"Sao Paulo - SP"}},"id":"3d016a74-7093-4811-95ed-c7bec788d558","type":"Circle"},{"attributes":{"data_source":{"id":"d0c74e17-d463-4558-9116-2a3cb40fa9ad","type":"ColumnDataSource"},"glyph":{"id":"e917b3aa-f96a-4e8c-b574-269a7040131f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bc816cfe-2048-4ca0-a266-4ae7090f94f1","type":"Circle"},"selection_glyph":null},"id":"b5aa653e-b85b-4959-9b0f-7a7593e75ca9","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Salvador - BA"},"renderers":[{"id":"a440b189-e5c0-4015-b32f-222395bcec56","type":"GlyphRenderer"}]},"id":"712b9ba0-1fbd-41e6-a61e-1de5f48c14ee","type":"LegendItem"},{"attributes":{"data_source":{"id":"d0c74e17-d463-4558-9116-2a3cb40fa9ad","type":"ColumnDataSource"},"glyph":{"id":"ff1d19f3-3218-408d-8131-43ac36b54872","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"cbfb015b-2969-461b-b7cd-3fc9a9551259","type":"Circle"},"selection_glyph":null},"id":"2300eff1-9ed5-4211-83de-9667f7273e9c","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"45a4a208-d14f-46e9-b30e-b4710a56fe4f","type":"ColumnDataSource"},"glyph":{"id":"3b42c8ed-e740-4ccc-853e-f3382682cd1b","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4369f474-da86-4740-b8ac-c20a15501ac0","type":"Line"},"selection_glyph":null},"id":"b92c72bf-0708-4537-a601-8dac083d7ba3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.3},"fill_color":{"value":"#377eb8"},"line_color":{"value":"#377eb8"},"x":{"field":"mes"},"y":{"field":"Salvador - BA"}},"id":"e831bca2-b1c5-4977-bb0d-f12b2537e794","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4369f474-da86-4740-b8ac-c20a15501ac0","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"mes"},"y":{"field":"Porto Alegre - RS"}},"id":"38969e5f-e95b-48b2-afdf-a359a0d8e157","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"94e46a16-dd0e-483d-81be-b380995c4a44","type":"BoxAnnotation"},{"attributes":{"label":{"value":"Porto Alegre - RS"},"renderers":[{"id":"8e860636-6661-4445-82f7-348333e93736","type":"GlyphRenderer"}]},"id":"e5f28577-ce7b-4bf5-82e7-93be2f7aba71","type":"LegendItem"},{"attributes":{},"id":"e520f11f-ac17-4c77-bf1e-200d186bc82e","type":"BasicTicker"},{"attributes":{"label":{"value":"Recife - PE"},"renderers":[{"id":"801ad2bd-0588-4896-9523-94551c96d3fc","type":"GlyphRenderer"}]},"id":"6fe04820-b826-4814-86c7-aad498ba9880","type":"LegendItem"},{"attributes":{"dimension":1,"plot":{"id":"86552f4a-95d4-44a0-a12a-be9524234ffd","subtype":"Figure","type":"Plot"},"ticker":{"id":"647bbd0f-a803-405d-b83c-5af8012c6448","type":"BasicTicker"}},"id":"c9b72db8-4cc5-44b1-bcd6-01bbf2c3a703","type":"Grid"},{"attributes":{"data_source":{"id":"d0c74e17-d463-4558-9116-2a3cb40fa9ad","type":"ColumnDataSource"},"glyph":{"id":"3b7c6cec-4413-404b-bc2a-a4ceffdbead3","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"38969e5f-e95b-48b2-afdf-a359a0d8e157","type":"Circle"},"selection_glyph":null},"id":"8e860636-6661-4445-82f7-348333e93736","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"mes"},"y":{"field":" ...

# %% [markdown]
# Podemos, finalmente, destacar os mandatos de cada presidente nesse período usando `BoxAnnotation` de Bokeh. Para isso, montamos uma tabela com os dados dos presidentes obtidos da Wikipedia e carregamos para um data frame.

# %%
presidentes = pd.read_csv('../2017.1/data/presidentes.csv',sep=';')
presidentes
# Out:
#                         nome                  inicio                     fim  \
# 0            Fernando Collor     15 de março de 1990  29 de dezembro de 1992
# 1              Itamar Franco  29 de dezembro de 1992    1 de janeiro de 1995
# 2  Fernando Henrique Cardoso    1 de janeiro de 1995    1 de janeiro de 2003
# 3  Luiz Inácio Lula da Silva    1 de janeiro de 2003    1 de janeiro de 2011
# 4             Dilma Rousseff    1 de janeiro de 2011    31 de agosto de 2016
# 5               Michel Temer    31 de agosto de 2016                     NaN
#
#   partido
# 0     PRN
# 1    PMDB
# 2    PSDB
# 3      PT
# 4      PT
# 5    PMDB

# %% [markdown]
# Ajustamos as datas para `datetime`.

# %%
presidentes.inicio = pd.to_datetime(presidentes.inicio,format='%d de %B de %Y')
presidentes.fim = pd.to_datetime(presidentes.fim,format='%d de %B de %Y')
presidentes.fim.fillna(ipcalong.mes.max(), inplace=True)
presidentes
# Out:
#                         nome     inicio        fim partido
# 0            Fernando Collor 1990-03-15 1992-12-29     PRN
# 1              Itamar Franco 1992-12-29 1995-01-01    PMDB
# 2  Fernando Henrique Cardoso 1995-01-01 2003-01-01    PSDB
# 3  Luiz Inácio Lula da Silva 2003-01-01 2011-01-01      PT
# 4             Dilma Rousseff 2011-01-01 2016-08-31      PT
# 5               Michel Temer 2016-08-31 2016-07-01    PMDB

# %% [markdown]
# Mapeamos os partidos a cores.

# %%
corPartido = dict(zip(presidentes.partido.unique(),['teal','orange','blue','red']))
corPartido
# Out:
# {'PMDB': 'orange', 'PRN': 'teal', 'PSDB': 'blue', 'PT': 'red'}

# %% [markdown]
# Criamos uma anotação para cada presidente.

# %%
boxes = presidentes.apply(lambda x: BoxAnnotation(left=x['inicio'].timestamp()*1000,\
                                                       right=x['fim'].timestamp()*1000,\
                                                       fill_color=corPartido[x['partido']],\
                                                       fill_alpha=0.1), \
                 axis=1).values

# %% [markdown]
# E adicionamos ao gráfico.

# %%
for b in boxes:
    p.add_layout(b)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="edda07f4-3037-4269-b464-428f6259cc45"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("edda07f4-3037-4269-b464-428f6259cc45");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("edda07f4-3037-4269-b464-428f6259cc45");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'edda07f4-3037-4269-b464-428f6259cc45' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b0e2a108-91c8-42e2-a398-12e0873cc962":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"mes"},"y":{"field":"Sao Paulo - SP"}},"id":"3d016a74-7093-4811-95ed-c7bec788d558","type":"Circle"},{"attributes":{"data_source":{"id":"d0c74e17-d463-4558-9116-2a3cb40fa9ad","type":"ColumnDataSource"},"glyph":{"id":"e917b3aa-f96a-4e8c-b574-269a7040131f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bc816cfe-2048-4ca0-a266-4ae7090f94f1","type":"Circle"},"selection_glyph":null},"id":"b5aa653e-b85b-4959-9b0f-7a7593e75ca9","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Salvador - BA"},"renderers":[{"id":"a440b189-e5c0-4015-b32f-222395bcec56","type":"GlyphRenderer"}]},"id":"712b9ba0-1fbd-41e6-a61e-1de5f48c14ee","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.3},"fill_color":{"value":"#b3de69"},"line_color":{"value":"#b3de69"},"x":{"field":"mes"},"y":{"field":"Recife - PE"}},"id":"c0c67a6f-bb50-4d79-b149-8752daa50e07","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"red"},"left":1293850800000.0,"plot":{"id":"86552f4a-95d4-44a0-a12a-be9524234ffd","subtype":"Figure","type":"Plot"},"right":1472612400000.0},"id":"1dc9e777-1072-4441-acc4-e875106fcb08","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"d0c74e17-d463-4558-9116-2a3cb40fa9ad","type":"ColumnDataSource"},"glyph":{"id":"ff1d19f3-3218-408d-8131-43ac36b54872","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"cbfb015b-2969-461b-b7cd-3fc9a9551259","type":"Circle"},"selection_glyph":null},"id":"2300eff1-9ed5-4211-83de-9667f7273e9c","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"45a4a208-d14f-46e9-b30e-b4710a56fe4f","type":"ColumnDataSource"},"glyph":{"id":"3b42c8ed-e740-4ccc-853e-f3382682cd1b","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4369f474-da86-4740-b8ac-c20a15501ac0","type":"Line"},"selection_glyph":null},"id":"b92c72bf-0708-4537-a601-8dac083d7ba3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.3},"fill_color":{"value":"#377eb8"},"line_color":{"value":"#377eb8"},"x":{"field":"mes"},"y":{"field":"Salvador - BA"}},"id":"e831bca2-b1c5-4977-bb0d-f12b2537e794","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4369f474-da86-4740-b8ac-c20a15501ac0","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"mes"},"y":{"field":"Porto Alegre - RS"}},"id":"38969e5f-e95b-48b2-afdf-a359a0d8e157","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"94e46a16-dd0e-483d-81be-b380995c4a44","type":"BoxAnnotation"},{"attributes":{"label":{"value":"Porto Alegre - RS"},"renderers":[{"id":"8e860636-6661-4445-82f7-348333e93736","type":"GlyphRenderer"}]},"id":"e5f28577-ce7b-4bf5-82e7-93be2f7aba71","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"red"},"left":1041390000000.0,"plot":{"id":"86552f4a-95d4-44a0-a12a-be9524234ffd","subtype":"Figure","type":"Plot"},"right":1293850800000.0},"id":"f53ba02f-3932-4f00-a711-713ca214813d","type":"BoxAnnotation"},{"attributes":{"label":{"value":"Recife - PE"},"renderers":[{"id":"801ad2bd-0588-4896-9523-94551c96d3fc","type":"GlyphRenderer"}]},"id":"6fe04820-b826-4814-86c7-aad498ba9880","type":"LegendItem"},{"attributes":{"dimension":1,"plot":{"id":"86552f4a-95d4-44a0-a12a-be9524234ffd","subtype":"Figure","type":"Plot"},"ticker" ...

# %% [markdown]
# Podemos ainda acrescentar a sigla do partido em cada região.

# %%
f = lambda x: (x['inicio'].timestamp()+(x['fim'].timestamp()+x['inicio'].timestamp())/2)*1000
from bokeh.models import Label
labels = presidentes.apply(lambda x: Label(text=x['partido'],x=f(x),y=0.7,text_font_size='10pt'),
                 axis=1).values

# %%
p.y_range = Range1d(0,0.7)

for l in labels:
    p.add_layout(l)

# %%
from bokeh.models import LabelSet
labelSource = ColumnDataSource(dict(x=presidentes['inicio'].map(lambda x: x.timestamp()*1000),
                                    y=np.repeat(0.55,presidentes.shape[0]),
                                   text=presidentes['partido']))
labels = LabelSet(x='x', y='y', text='text',
         x_offset=5, y_offset=5, source=labelSource, text_font_size='8pt')
p.add_layout(labels)

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4ce45411-4444-4026-a279-2520fd97c16e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4ce45411-4444-4026-a279-2520fd97c16e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4ce45411-4444-4026-a279-2520fd97c16e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4ce45411-4444-4026-a279-2520fd97c16e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6815dc3e-6766-4828-a64b-deedb252e491":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"mes"},"y":{"field":"Sao Paulo - SP"}},"id":"3d016a74-7093-4811-95ed-c7bec788d558","type":"Circle"},{"attributes":{"data_source":{"id":"d0c74e17-d463-4558-9116-2a3cb40fa9ad","type":"ColumnDataSource"},"glyph":{"id":"e917b3aa-f96a-4e8c-b574-269a7040131f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bc816cfe-2048-4ca0-a266-4ae7090f94f1","type":"Circle"},"selection_glyph":null},"id":"b5aa653e-b85b-4959-9b0f-7a7593e75ca9","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Salvador - BA"},"renderers":[{"id":"a440b189-e5c0-4015-b32f-222395bcec56","type":"GlyphRenderer"}]},"id":"712b9ba0-1fbd-41e6-a61e-1de5f48c14ee","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"red"},"left":1293850800000.0,"plot":{"id":"86552f4a-95d4-44a0-a12a-be9524234ffd","subtype":"Figure","type":"Plot"},"right":1472612400000.0},"id":"1dc9e777-1072-4441-acc4-e875106fcb08","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"d0c74e17-d463-4558-9116-2a3cb40fa9ad","type":"ColumnDataSource"},"glyph":{"id":"ff1d19f3-3218-408d-8131-43ac36b54872","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"cbfb015b-2969-461b-b7cd-3fc9a9551259","type":"Circle"},"selection_glyph":null},"id":"2300eff1-9ed5-4211-83de-9667f7273e9c","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"1b421937-ea31-46b3-829d-e9a27b8b0a27","type":"BoxAnnotation"},"plot":{"id":"86552f4a-95d4-44a0-a12a-be9524234ffd","subtype":"Figure","type":"Plot"}},"id":"b421ab4c-4008-498f-a9bd-8da7933c1ba8","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"45a4a208-d14f-46e9-b30e-b4710a56fe4f","type":"ColumnDataSource"},"glyph":{"id":"3b42c8ed-e740-4ccc-853e-f3382682cd1b","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4369f474-da86-4740-b8ac-c20a15501ac0","type":"Line"},"selection_glyph":null},"id":"b92c72bf-0708-4537-a601-8dac083d7ba3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.3},"fill_color":{"value":"#377eb8"},"line_color":{"value":"#377eb8"},"x":{"field":"mes"},"y":{"field":"Salvador - BA"}},"id":"e831bca2-b1c5-4977-bb0d-f12b2537e794","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4369f474-da86-4740-b8ac-c20a15501ac0","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"mes"},"y":{"field":"Porto Alegre - RS"}},"id":"38969e5f-e95b-48b2-afdf-a359a0d8e157","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"94e46a16-dd0e-483d-81be-b380995c4a44","type":"BoxAnnotation"},{"attributes":{"label":{"value":"Porto Alegre - RS"},"renderers":[{"id":"8e860636-6661-4445-82f7-348333e93736","type":"GlyphRenderer"}]},"id":"e5f28577-ce7b-4bf5-82e7-93be2f7aba71","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"red"},"left":1041390000000.0,"plot":{"id":"86552f4a-95d4-44a0-a12a-be9524234ffd","subtype":"Figure","type":"Plot"},"right":1293850800000.0},"id":"f53ba02f-3932-4f00-a711-713ca214813d","type":"BoxAnnotation"},{"attributes":{"label":{"value":"Recife - PE"},"renderers":[{"id":"801ad2bd-0588-4896-9523-94551c96d3fc","type":"GlyphRenderer"}]},"id":"6fe04820-b826-4814-86c7-aad498ba9880","type":"LegendItem"},{"attributes":{"dimension":1,"plot":{"id":"86552f4a-95d4-44a0-a12a-be9524234ffd","subtype":"Fi ...

# %% [markdown]
# Ainda que seja útil destacar os períodos de cada presidente, o usuário pode querer destacar um único período/presidente. Assim, seria interessante acrescentar alguns checkboxes à visualização que permitissem marcar ou desmarcar um período/presidente.
#
# Essa funcionalidade requer o uso de um callback, que deve ser escrito em Javascipt, responsável por atualizar a visualização como resultado do evento de marcar ou desmarcar o checkbox. Veremos como criar tal interatividade.

# %%
from bokeh.models import CustomJS, CheckboxGroup
from bokeh.layouts import widgetbox

boxes = presidentes.apply(lambda x: BoxAnnotation(left=x['inicio'].timestamp()*1000,\
                                                       right=x['fim'].timestamp()*1000,\
                                                       fill_color=corPartido[x['partido']],\
                                                       fill_alpha=0.1), \
                 axis=1).values

code = '''\
for(i=0; i < ckbox.labels.length; i++){
    if(ckbox.active.indexOf(i)>-1){//i is active
       box = eval('box'+i)
       box.fill_alpha = 0.1
       box.line_alpha = 1    
    } else{
       box = eval('box'+i)
       box.fill_alpha = 0
       box.line_alpha = 0    
    }
}
'''
callback = CustomJS(code=code, args={})
checkbox_group = CheckboxGroup(
        labels=presidentes.nome.values.tolist(), active=list(range(len(boxes))), 
    callback=callback)

#toggle = Toggle(label="Red Box", button_type="success", callback=callback)
callback.args = {'ckbox': checkbox_group}
callback.args.update(dict(zip(['box{}'.format(a) for a in range(len(boxes))],boxes)))

# %%
p = figure(plot_height=400,plot_width=800,toolbar_location='below',
           tools="pan,box_select,tap,box_zoom,lasso_select,reset",
          toolbar_sticky=False)

p.xaxis.formatter = DatetimeTickFormatter(months='%b/%Y')
p.yaxis.formatter = NumeralTickFormatter(format='0.00%')

glyphs = {d : [p.circle('mes',d,source=source,
                        color=corRegiao[d], fill_alpha=0.3)] 
          for d in ipcalong.Regiao.unique()}
legend = Legend(items=list(glyphs.items()), location=(10, 50))
legend.click_policy='hide'
p.add_layout(legend,'right')

for b in boxes:
    p.add_layout(b)

show(gridplot([[p,checkbox_group]], 
              toolbar_location='below',
             sizing_mode="scale_width"))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="
type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.3},"fill_color":{"value":"#fb8072"},"line_color":{"value":"#fb8072"},"x":{"field":"mes"},"y":{"field":"Fortaleza - CE"}},"id":"a158eab6-f310-4c15-9116-718561e50065","type":"Circle"},{"attributes":{"plot":{"id":"9d01ee7f-69a8-442e-8ad4-77efb55fd6b8","subtype":"Figure","type":"Plot"}},"id":"1a56dd7e-9b2f-4b52-ae30-9708832c467e","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0. ...

# %% [markdown]
# Outro recurso interessante de Bokeh é a possibilidade de associar os eixos dos diversos gráficos da visualização. Podemos fazer com que a seleção de dados num gráfico seja refletida em outros gráficos da visualização compartilhando os eixos entre eles. No exemplo a seguir, plotaremos o índice geral do IPCA e os componentes de habitação, alimentação e educação em uma única visualização (quatro gráficos distintos). Vamos associar os eixos e dados desses gráficos de forma que a interação do usuário com qualquer deles seja refletida nos demais.

# %%
d2 = ipcalong[(ipcalong.Regiao=='Recife - PE')]
s = ColumnDataSource(pd.pivot_table(d2,columns='OPCAO',values='ipca',index='mes'))

# %%
p = figure(plot_width=400, plot_height=400, title='Geral',
           tools="pan,box_select,tap,box_zoom,lasso_select,reset")
p.line(x='mes', y='Indice geral',color="firebrick", source=s)
p.xaxis.formatter = DatetimeTickFormatter(months='%b/%Y')
p.yaxis.formatter = NumeralTickFormatter(format='0.00%')

p2 = figure(plot_width=400, plot_height=400, x_range = p.x_range, 
            y_range = p.y_range, title='Alimentação',
            tools="pan,box_select,tap,box_zoom,lasso_select,reset")
p2.line(x='mes', y='1,Alimentacao e bebidas',color="firebrick", source=s)
p2.xaxis.formatter = DatetimeTickFormatter(months='%b/%Y')
p2.yaxis.formatter = NumeralTickFormatter(format='0.00%')

p3 = figure(plot_width=400, plot_height=400, x_range = p.x_range, 
            y_range = p.y_range, 
            title='Habitação',
            tools="pan,box_select,tap,box_zoom,lasso_select,reset")
p3.line(x='mes', y='2,Habitacao',color="firebrick", source=s)
p3.xaxis.formatter = DatetimeTickFormatter(months='%b/%Y')
p3.yaxis.formatter = NumeralTickFormatter(format='0.00%')

p4 = figure(plot_width=400, plot_height=400, 
            x_range = p.x_range, y_range = p.y_range, 
            title='Educação',
            tools="pan,box_select,tap,box_zoom,lasso_select,reset")
p4.line(x='mes', y='8,Educacao',color="firebrick",source=s)
p4.xaxis.formatter = DatetimeTickFormatter(months='%b/%Y')
p4.yaxis.formatter = NumeralTickFormatter(format='0.00%')

show(gridplot([[p,p2],[p3,p4]]))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="947538ed-9017-437a-b4f7-152f479e06e4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("947538ed-9017-437a-b4f7-152f479e06e4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("947538ed-9017-437a-b4f7-152f479e06e4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '947538ed-9017-437a-b4f7-152f479e06e4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"aad869af-aa3d-48d1-9574-947c0383dfb4":{"roots":{"references":[{"attributes":{"callback":null,"overlay":{"id":"bc7b6b12-1c20-49a9-b1bf-33520a6ef6e3","type":"BoxAnnotation"},"plot":{"id":"67f87708-24d1-4c47-b5d3-ce81987dd236","subtype":"Figure","type":"Plot"},"renderers":[{"id":"6fb21b63-8f6d-4791-a63a-941b54af9d55","type":"GlyphRenderer"}]},"id":"cb785531-f310-4186-a1c3-cf5f7e7f1d07","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"00fd8868-381c-48f2-8061-814ff9373ba9","subtype":"Figure","type":"Plot"}},"id":"27e9b34e-8609-4bd5-917d-b6b41366db07","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":